# %% [markdown]
# # encoding of the dataset

# %%
import pandas as pd 
data = {'Name' : ['Dhruv','Prit','Krish','Shubham'],
        'Age' : [20,22,23,24],
        'Salary' :[20000,22500,17500,21500],
        'City' : ['Surat', 'Bharuch' , 'Surat','Bhavnagar']}

df = pd.DataFrame(data)
df.to_csv('Employee.csv', index=False)
print(df)
# Out:
#       Name  Age  Salary       City
# 0    Dhruv   20   20000      Surat
# 1     Prit   22   22500    Bharuch
# 2    Krish   23   17500      Surat
# 3  Shubham   24   21500  Bhavnagar

# %%
import sklearn 
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('Employee.csv')
df_label = df.copy()

# %%
le = LabelEncoder()

# %%
df_label['City_encoder'] = le.fit_transform(df_label['City'])
print(df_label)
# Out:
#       Name  Age  Salary       City  City_encoder
# 0    Dhruv   20   20000      Surat             2
# 1     Prit   22   22500    Bharuch             0
# 2    Krish   23   17500      Surat             2
# 3  Shubham   24   21500  Bhavnagar             1
