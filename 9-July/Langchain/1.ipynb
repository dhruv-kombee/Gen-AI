# %% [markdown]
# Langchain Practice

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

# %%
from dotenv import load_dotenv
import os

load_dotenv()

llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite", temperature=0 , max_output_tokens=1024)

# %%
result = llm.invoke("What is the ART")

print(result.content[0]["text"])
# Out:
# The term **ART** can refer to several different things depending on the context. Here are the most common meanings:
#
# ### 1. The Creative Arts (General Definition)
# In the broadest sense, **art** is the expression or application of human creative skill and imagination. It typically produces works to be appreciated primarily for their beauty or emotional power. This includes:
# *   **Visual Arts:** Painting, drawing, sculpture, photography, and architecture.
# *   **Performing Arts:** Music, dance, theater, and film.
# *   **Literary Arts:** Poetry, novels, and essays.
#
# ### 2. Assisted Reproductive Technology (Medical)
# In medicine, **ART** stands for **Assisted Reproductive Technology**. This refers to fertility treatments used to help people conceive a child. It involves handling both eggs and sperm. Common examples include:
# *   **IVF (In Vitro Fertilization):** The most common form of ART, where eggs are fertilized by sperm in a laboratory dish and then implanted into the uterus.
# *   **GIFT (Gamete Intrafallopian Transfer):** Placing eggs and sperm into the fallopian tubes.
# *   **ZIFT (Zygote Intrafallopian Transfer):** Placing a fertilized egg into the fallopian tubes.
#
# ### 3. Antiretroviral Therapy (Medicine/HIV)
# In the context of HIV/AIDS treatment, **ART** stands for **Antiretroviral Therapy**. It is the daily use of a combination of HIV medicines to treat HIV infection. While it does not cure HIV, it suppresses the virus to undetectable levels, allowing people with HIV to live long, healthy lives and preventing the transmission of the virus to others.
#
# ### 4. Agile Release Train (Business/Software)
# In the world of software development and project management (specifically the **Scaled Agile Framework** or SAFe), **ART** stands for **Agile Release Train**. It is a long-lived team of Agile teams that, along with other stakeholders, incrementally develops, delivers, and where applicable, operates one or more solutions in a value stream.
#
# ### 5. Art (The Programming Language)
# There is a programming language called **ART** (Adaptive Recognition Technology), though it is less common than the others listed above. It is sometimes associated with neural network research and pattern recognition.
#
# ***
#
# **Which one were you looking for?** If you can provide a little more context (e.g., "ART in medicine" or "ART in school"), I can give you a much more detailed answer!
