# %% [markdown]
# # Embedding Application

# %%
from dotenv import load_dotenv
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
load_dotenv()
# Out:
# True

# %%
embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001" , dimension=300)

# %%
documents = [
    "Artificial Intelligence is transforming the world.",
    "Human philosophy is the study of fundamental questions about existence, knowledge, values, reason, mind, and language.",
    "Medicine is now became cheaper and more accurate by researching ",
    "AI is being applied in various industries.",
    "Cricket is the most popular sport in India."
    "Artificial Intelligence is transforming the world.",
    "Machine Learning is a subset of AI.",
    "Deep Learning uses neural networks.",
    "LangChain simplifies LLM application development."
]

# %%
query = "What is Human philosopy"

# %%
doc_embeddings = embeddings.embed_documents(documents)
query_embedding = embeddings.embed_query(query)

# %%
cosine_similarities = cosine_similarity([query_embedding], doc_embeddings)[0]

# %%
print("Cosine Similarities:", cosine_similarities)
# Out:
# Cosine Similarities: [0.59620671 0.78556947 0.56363225 0.57128368 0.59301894 0.58350799
#  0.56077698 0.54299754]

# %%
index , score = sorted(list(enumerate(cosine_similarities)), key=lambda x: x[1],)[-1]
print(f"Index: {index}, Score: {score}")
# Out:
# Index: 1, Score: 0.7855694677898313

# %%
print(query)
print("Simiar Document:", documents[index])
# Out:
# What is Human philosopy
# Simiar Document: Human philosophy is the study of fundamental questions about existence, knowledge, values, reason, mind, and language.
