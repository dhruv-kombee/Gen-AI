# %% [markdown]
# # Q1 load

# %%
import pandas as pd

# %%
df = pd.read_csv("student.csv")
print(df)
# Out:
#    StudentID   Name  Age Department  Marks  Attendance       City
# 0        101  Dhruv   21         IT   85.0        92.0      Surat
# 1        102    Raj   20         IT   78.0        88.0  Ahmedabad
# 2        103    Jay   22         CS   91.0        95.0      Surat
# 3        104  Priya   21         CS    NaN        90.0     Baroda
# 4        105   Neha   20         IT   67.0        85.0     Rajkot
# 5        106   Amit   23         EC   88.0         NaN  Ahmedabad
# 6        107  Karan   22         EC   73.0        80.0      Surat
# 7        108   Riya   21         CS   95.0        98.0     Baroda
# 8        109  Vikas   24         IT   82.0        87.0      Surat
# 9        110  Pooja   20         EC   76.0        84.0     Rajkot

# %%
#Q2
print("First Five Record : \n",df.head())
print("\n\nLast Five Record : \n",df.tail())
# Out:
# First Five Record :
#     StudentID   Name  Age Department  Marks  Attendance       City
# 0        101  Dhruv   21         IT   85.0        92.0      Surat
# 1        102    Raj   20         IT   78.0        88.0  Ahmedabad
# 2        103    Jay   22         CS   91.0        95.0      Surat
# 3        104  Priya   21         CS    NaN        90.0     Baroda
# 4        105   Neha   20         IT   67.0        85.0     Rajkot
#
#
# Last Five Record :
#     StudentID   Name  Age Department  Marks  Attendance       City
# 5        106   Amit   23         EC   88.0         NaN  Ahmedabad
# 6        107  Karan   22         EC   73.0        80.0      Surat
# 7        108   Riya   21         CS   95.0        98.0     Baroda
# 8        109  Vikas   24         IT   82.0        87.0      Surat
# 9        110  Pooja   20         EC   76.0        84.0     Rajkot

# %%
# Q3 and Q4
print("Number or row and column : ", df.shape)
print("Number or row and column : ", df.columns)
# Out:
# Number or row and column :  (10, 7)
# Number or row and column :  Index(['StudentID', 'Name', 'Age', 'Department', 'Marks', 'Attendance',
#        'City'],
#       dtype='str')

# %%
#Q5
print("Data type of the all column : \n ",df.dtypes)
# Out:
# Data type of the all column :
#   StudentID       int64
# Name              str
# Age             int64
# Department        str
# Marks         float64
# Attendance    float64
# City              str
# dtype: object

# %%
#Q6
print("Complete information about the dataset : \n", df.info)
# Out:
# Complete information about the dataset :
#  <bound method DataFrame.info of    StudentID   Name  Age Department  Marks  Attendance       City
# 0        101  Dhruv   21         IT   85.0        92.0      Surat
# 1        102    Raj   20         IT   78.0        88.0  Ahmedabad
# 2        103    Jay   22         CS   91.0        95.0      Surat
# 3        104  Priya   21         CS    NaN        90.0     Baroda
# 4        105   Neha   20         IT   67.0        85.0     Rajkot
# 5        106   Amit   23         EC   88.0         NaN  Ahmedabad
# 6        107  Karan   22         EC   73.0        80.0      Surat
# 7        108   Riya   21         CS   95.0        98.0     Baroda
# 8        109  Vikas   24         IT   82.0        87.0      Surat
# 9        110  Pooja   20         EC   76.0        84.0     Rajkot>

# %%
#Q7 and Q8
print("display of the only name column : \n", df['Name'])
print("display of the only name column : \n", df[["Name","Department","Marks"]])
# Out:
# display of the only name column :
#  0    Dhruv
# 1      Raj
# 2      Jay
# 3    Priya
# 4     Neha
# 5     Amit
# 6    Karan
# 7     Riya
# 8    Vikas
# 9    Pooja
# Name: Name, dtype: str
# display of the only name column :
#      Name Department  Marks
# 0  Dhruv         IT   85.0
# 1    Raj         IT   78.0
# 2    Jay         CS   91.0
# 3  Priya         CS    NaN
# 4   Neha         IT   67.0
# 5   Amit         EC   88.0
# 6  Karan         EC   73.0
# 7   Riya         CS   95.0
# 8  Vikas         IT   82.0
# 9  Pooja         EC   76.0

# %%
#9 and #10
print("First row only :\n " , df.head(1))
print("\n3rd to 7th row :\n" , df.iloc[3:8])
# Out:
# First row only :
#      StudentID   Name  Age Department  Marks  Attendance   City
# 0        101  Dhruv   21         IT   85.0        92.0  Surat
#
# 3rd to 7th row :
#     StudentID   Name  Age Department  Marks  Attendance       City
# 3        104  Priya   21         CS    NaN        90.0     Baroda
# 4        105   Neha   20         IT   67.0        85.0     Rajkot
# 5        106   Amit   23         EC   88.0         NaN  Ahmedabad
# 6        107  Karan   22         EC   73.0        80.0      Surat
# 7        108   Riya   21         CS   95.0        98.0     Baroda

# %%
#Q11
print("\ndisplay student id and marks for the first 5 student : \n ", df[["StudentID","Marks"]].head())
# Out:
# display student id and marks for the first 5 student :
#      StudentID  Marks
# 0        101   85.0
# 1        102   78.0
# 2        103   91.0
# 3        104    NaN
# 4        105   67.0

# %%
#12
mark = df[df["Marks"] > 80]
print(mark)
# Out:
#    StudentID   Name  Age Department  Marks  Attendance       City
# 0        101  Dhruv   21         IT   85.0        92.0      Surat
# 2        103    Jay   22         CS   91.0        95.0      Surat
# 5        106   Amit   23         EC   88.0         NaN  Ahmedabad
# 7        108   Riya   21         CS   95.0        98.0     Baroda
# 8        109  Vikas   24         IT   82.0        87.0      Surat

# %%
city = df[df["City"] == "Surat"]
print(city)
# Out:
#    StudentID   Name  Age Department  Marks  Attendance   City
# 0        101  Dhruv   21         IT   85.0        92.0  Surat
# 2        103    Jay   22         CS   91.0        95.0  Surat
# 6        107  Karan   22         EC   73.0        80.0  Surat
# 8        109  Vikas   24         IT   82.0        87.0  Surat

# %%
att = df[df["Attendance"] >= 90]
print(att)
# Out:
#    StudentID   Name  Age Department  Marks  Attendance    City
# 0        101  Dhruv   21         IT   85.0        92.0   Surat
# 2        103    Jay   22         CS   91.0        95.0   Surat
# 3        104  Priya   21         CS    NaN        90.0  Baroda
# 7        108   Riya   21         CS   95.0        98.0  Baroda

# %%
deptIT = df[df["Department"] == "IT"]
print(deptIT)
# Out:
#    StudentID   Name  Age Department  Marks  Attendance       City
# 0        101  Dhruv   21         IT   85.0        92.0      Surat
# 1        102    Raj   20         IT   78.0        88.0  Ahmedabad
# 4        105   Neha   20         IT   67.0        85.0     Rajkot
# 8        109  Vikas   24         IT   82.0        87.0      Surat

# %%
dp = df[(df["Marks"] >= 80) & (df["Department"] == "IT")]
print(dp)
# Out:
#    StudentID   Name  Age Department  Marks  Attendance   City
# 0        101  Dhruv   21         IT   85.0        92.0  Surat
# 8        109  Vikas   24         IT   82.0        87.0  Surat

# %%
dpcity = df[(df["City"] == "Surat") | (df["City"] == "Ahmedabad")]
print(dpcity)
# Out:
#    StudentID   Name  Age Department  Marks  Attendance       City
# 0        101  Dhruv   21         IT   85.0        92.0      Surat
# 1        102    Raj   20         IT   78.0        88.0  Ahmedabad
# 2        103    Jay   22         CS   91.0        95.0      Surat
# 5        106   Amit   23         EC   88.0         NaN  Ahmedabad
# 6        107  Karan   22         EC   73.0        80.0      Surat
# 8        109  Vikas   24         IT   82.0        87.0      Surat

# %%
mark = df[(df["Marks"] > 70) & (df["Marks"]<90)]
print(mark)
# Out:
#    StudentID   Name  Age Department  Marks  Attendance       City
# 0        101  Dhruv   21         IT   85.0        92.0      Surat
# 1        102    Raj   20         IT   78.0        88.0  Ahmedabad
# 5        106   Amit   23         EC   88.0         NaN  Ahmedabad
# 6        107  Karan   22         EC   73.0        80.0      Surat
# 8        109  Vikas   24         IT   82.0        87.0      Surat
# 9        110  Pooja   20         EC   76.0        84.0     Rajkot
