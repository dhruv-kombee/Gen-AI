# %% [markdown]
# # Module 11–15 Notes
#
# ## M11 — Chain-of-Thought
# Makes LLM reason step by step.
#
# Key: Useful for reasoning-heavy tasks.
#
# ---
#
# ## M12 — Advanced Reasoning
# Techniques:
# - Self-Consistency
# - Tree of Thought
# - ReAct
# - Reflection
#
# Key: Improves complex reasoning.
#
# ---
#
# ## M13 — Prompt Chaining
# Split complex tasks into multiple prompts.
#
# Example:
# Extract → Analyze → Report
#
# Key: Better workflow control.
#
# ---
#
# ## M14 — Hallucination Reduction
# Reduce false outputs by:
# - Giving context
# - Restricting assumptions
# - Reducing ambiguity
#
# Key: Better context reduces hallucinations.
#
# ---
#
# ## M15 — Prompt Optimization
# Improve prompts using iteration.
#
# Workflow:
# Prompt → Test → Improve
#
# Key: Good prompts evolve through testing.
